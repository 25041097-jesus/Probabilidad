# %% [markdown]
# <a href="https://colab.research.google.com/github/25041097-jesus/Probabilidad/blob/main/Unidad1/Practica%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Probabilidad y estadistica**
#
# Unidad 1
#
# **Practica 2: Maximo,minimo,rango y dispersion de datos.**
#
# Docente: Dr. Jose Gabriel Rodriguez Rivas
#
# Alumno: Joan Jesus Varela Cervantes

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
# generamos 100 numeros aleatorios que representan la produccion
# en metros de tela de 100 dias
fabrica1=[]
for i in range (100):
    numero_aleatorio=round(random.uniform(50,100),2)
    fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [76.22, 98.66, 95.3, 51.15, 55.76, 63.82, 54.35, 95.42, 93.59, 85.49, 75.2, 73.08, 90.92, 89.93, 77.33, 61.78, 74.26, 80.9, 54.49, 91.98, 53.54, 73.03, 92.58, 50.67, 92.35, 81.94, 72.21, 55.76, 90.26, 60.96, 52.94, 73.91, 94.77, 51.29, 55.76, 50.91, 75.19, 93.99, 72.22, 63.43, 97.05, 94.21, 68.16, 93.32, 85.35, 61.7, 91.27, 87.1, 85.26, 89.4, 86.39, 79.44, 60.46, 91.48, 84.65, 97.6, 88.97, 97.94, 67.26, 58.1, 93.54, 52.16, 50.82, 91.39, 82.02, 57.7, 87.27, 69.45, 52.55, 63.34, 95.98, 98.76, 85.39, 74.26, 81.42, 88.92, 51.27, 89.46, 60.62, 70.3, 99.93, 57.67, 75.67, 90.77, 85.78, 55.44, 79.31, 93.76, 54.43, 68.5, 59.28, 55.92, 55.3, 97.46, 83.72, 62.72, 57.38, 82.84, 67.68, 65.79]

# %%
fabrica2=[]
for i in range (100):
  numero_aleatorio=round(random.uniform(50,100),2)
  fabrica2.append(numero_aleatorio)
print(fabrica2)
# Out:
# [83.94, 86.47, 53.81, 78.44, 57.97, 53.82, 79.14, 98.75, 60.82, 86.75, 60.67, 98.45, 97.15, 77.06, 91.31, 68.83, 91.57, 54.57, 94.43, 62.18, 97.64, 71.87, 75.53, 85.68, 51.48, 81.66, 57.32, 61.92, 90.37, 53.82, 94.27, 81.53, 95.97, 78.62, 61.01, 99.55, 51.82, 93.0, 71.09, 84.32, 81.68, 99.74, 94.56, 67.47, 65.07, 62.83, 65.28, 61.84, 71.56, 93.47, 91.52, 57.63, 80.95, 90.98, 63.88, 77.05, 60.07, 91.78, 88.07, 71.76, 79.24, 87.51, 58.71, 63.95, 50.43, 65.16, 97.57, 90.97, 62.9, 65.66, 58.42, 76.63, 56.02, 57.45, 50.83, 52.46, 86.88, 50.82, 54.52, 86.36, 51.77, 98.4, 87.53, 97.8, 72.2, 96.21, 94.31, 53.85, 84.82, 85.2, 61.74, 59.6, 56.87, 97.93, 99.56, 93.66, 91.49, 66.49, 88.33, 56.89]

# %%
maximo1=max(fabrica1)
minimo1=min(fabrica1)
rango1=maximo1-minimo1
media1=mean(fabrica1)
mediana1=median(fabrica1)
moda1=mode(fabrica1)
desviacion_estandar_fabrica1=stdev(fabrica1)
print("Estadistica descriptiva de la fabrica 1\n",
      "media=",media1,
      "\n mediana=",mediana1,
      "\n moda=",moda1,
      "\n desviacion estandar=",desviacion_estandar_fabrica1,
      "\n rango=",rango1,
      "\n minimo=",minimo1,
      "\n maximo=",maximo1)
# Out:
# Estadistica descriptiva de la fabrica 1
#  media= 75.5842
#  mediana= 75.945
#  moda= 55.76
#  desviacion estandar= 15.78135878852392
#  rango= 49.260000000000005
#  minimo= 50.67
#  maximo= 99.93

# %%
maximo2=max(fabrica2)
minimo2=min(fabrica2)
rango2=maximo2-minimo2
media2=mean(fabrica2)
mediana2=median(fabrica2)
moda2=mode(fabrica2)
desviacion_estandar_fabrica2=stdev(fabrica2)
print("Estadistica descriptiva de la fabrica 2\n",
      "media=",media2,
      "\n mediana=",mediana2,
      "\n moda=",moda2,
      "\n desviacion estandar=",desviacion_estandar_fabrica2,
      "\n rango=",rango2,
      "\n minimo=",minimo2,
      "\n maximo=",maximo2)
# Out:
# Estadistica descriptiva de la fabrica 2
#  media= 75.5893
#  mediana= 77.055
#  moda= 53.82
#  desviacion estandar= 16.09396751625097
#  rango= 49.309999999999995
#  minimo= 50.43
#  maximo= 99.74

# %%
plt.figure(figsize=(8,6))
plt.hist(fabrica1,bins=10,alpha=0.2,color='b',edgecolor="black")
plt.axvline(media1,color='b',linestyle='dashed',linewidth=2,label=f'media={media1:2f}')
plt.axvline(mediana1,color='r',linestyle='dashed',linewidth=2,label=f'mediana={mediana1:2f}')
plt.axvline(moda1,color='y',linestyle='dashed',linewidth=2,label=f'moda={moda1:2f}')
plt.axvline(media1 - desviacion_estandar_fabrica1,color='black',linestyle='dashed',linewidth=2,label=f'desviacion estandar={desviacion_estandar_fabrica1:2f}')
plt.axvline(media1 + desviacion_estandar_fabrica1,color='black',linestyle='dashed',linewidth=2)
plt.xlabel('valor')
plt.ylabel('frecuencia')
plt.title('produccion diaria de la fabrica 1')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.hist(fabrica2,bins=10,alpha=0.2,color='b',edgecolor="black")
plt.axvline(media2,color='b',linestyle='dashed',linewidth=2,label=f'media={media2:2f}')
plt.axvline(mediana2,color='r',linestyle='dashed',linewidth=2,label=f'mediana={mediana2:2f}')
plt.axvline(moda2,color='y',linestyle='dashed',linewidth=2,label=f'moda={moda2:2f}')
plt.axvline(media2 - desviacion_estandar_fabrica2,color='black',linestyle='dashed',linewidth=2,label=f'desviacion estandar={desviacion_estandar_fabrica2:2f}')
plt.axvline(media1 + desviacion_estandar_fabrica2,color='black',linestyle='dashed',linewidth=2)
plt.xlabel('valor')
plt.ylabel('frecuencia')
plt.title('produccion diaria de la fabrica 2')
plt.legend()
plt.show()

# %%
import seaborn as sns
sns.histplot( x = fabrica1, kde = True, kde_kws ={'bw_adjust':0.5}, bins = 10)
# Out:
# <Axes: ylabel='Count'>

# %%
import seaborn as sns
sns.histplot( x = fabrica2, kde = True, kde_kws ={'bw_adjust':0.5}, bins = 10)
# Out:
# <Axes: ylabel='Count'>
